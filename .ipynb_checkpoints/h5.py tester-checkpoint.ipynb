# %% [markdown]
# ### Kolla h5-filen ###

# %%
import numpy as np
import h5py

# %%
f = h5py.File('./datasets/train_signs.h5', 'r')

# %%
list(f.keys())
# Out:
# ['list_classes', 'train_set_x', 'train_set_y']

# %%
train_x = f["train_set_x"]

# %%
print(train_x.shape)
print(type(train_x))
# Out:
# (1080, 64, 64, 3)
# <class 'h5py._hl.dataset.Dataset'>

# %%
train_set_x_orig = np.array(train_x[:])

# %%
print(train_set_x_orig.shape)
print(type(train_set_x_orig))
print(train_set_x_orig)
# Out:
# (1080, 64, 64, 3)
# <class 'numpy.ndarray'>
# [[[[227 220 214]
#    [227 221 215]
#    [227 222 215]
#    ...,
#    [232 230 224]
#    [231 229 222]
#    [230 229 221]]
#
#   [[227 221 214]
#    [227 221 215]
#    [228 221 215]
#    ...,
#    [232 230 224]
#    [231 229 222]
#    [231 229 221]]
#
#   [[227 221 214]
#    [227 221 214]
#    [227 221 215]
#    ...,
#    [232 230 224]
#    [231 229 223]
#    [230 229 221]]
#
#   ...,
#   [[119  81  51]
#    [124  85  55]
#    [127  87  58]
#    ...,
#    [210 211 211]
#    [211 212 210]
#    [210 211 210]]
#
#   [[119  79  51]
#    [124  84  55]
#    [126  85  56]
#    ...,
#    [210 211 210]
#    [210 211 210]
#    [209 210 209]]
#
#   [[119  81  51]
#    [123  83  55]
#    [122  82  54]
#    ...,
#    [209 210 210]
#    [209 210 209]
#    [208 209 209]]]
#
#
#  [[[238 232 223]
#    [238 232 223]
#    [238 232 223]
#    ...,
#    [222 216 209]
#    [221 216 207]
#    [221 216 206]]
#
#   [[237 232 223]
#    [238 232 223]
# ...
